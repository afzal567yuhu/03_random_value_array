# %%
import numpy as np

# %% [markdown]
# RANDOM

# %% [markdown]
# RAND()

# %%
var = np.random.rand(5)
var
# Out:
# array([0.9283783 , 0.80800316, 0.59006592, 0.51550163, 0.66787045])

# %% [markdown]
# RANDN()

# %%
var_1 = np.random.randn(2)
var_1
# Out:
# array([ 0.80372328, -1.59740474])

# %% [markdown]
# RANF()

# %%
var_2 = np.random.ranf(6)
var_2
# Out:
# array([0.42275605, 0.17888754, 0.52965644, 0.58410027, 0.27953307,
#        0.21480312])

# %% [markdown]
# RANDINT

# %%
var_3 = np.random.randint(1,10,2)
var_3
# Out:
# array([2, 5], dtype=int32)
